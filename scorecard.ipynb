# %% [markdown]
# # Generating scorecard based on results from grid search, Optuna TPE and RL

# %%
import optimizer
opt = optimizer.Optimizer('sqlite:///scorecard.db')
opt.show_all_results()
# Out:
# # Level 17
# ## Optimization results from grid
# [I 2022-07-11 15:07:48,343] Using an existing study with name 'grid-17' instead of creating a new one.
# ## Optimization results from optuna
# [I 2022-07-11 15:07:49,964] Using an existing study with name 'optuna-17' instead of creating a new one.
# ## Optimization results from rl
# [I 2022-07-11 15:07:50,836] Using an existing study with name 'rl-17' instead of creating a new one.
# ## Summary
#          baseline   grid grid / baseline optuna optuna / baseline  \
# Level 17    10.09  10.09            0.0%  10.10              0.1%
#
#          optuna / grid     rl rl / baseline rl / grid rl / optuna
# Level 17          0.1%  10.85          7.6%      7.6%        7.5%
# # Level 60
# ## Optimization results from grid
# [I 2022-07-11 15:07:52,023] Using an existing study with name 'grid-60' instead of creating a new one.
# ## Optimization results from optuna
# ...

# %% [markdown]
# ## Generate final scorecard

# %%
opt.generate_rl_scorecard([
    (695, 'TS1'),
    (220, 'TS2'),
    (612, 'TS3'),
    (75, 'TS4'),
    (60, 'TS5'),
    (17, 'TS6'),
])
# Out:
# [I 2022-07-11 15:08:11,781] Using an existing study with name 'rl-695' instead of creating a new one.
# [I 2022-07-11 15:08:12,060] Using an existing study with name 'rl-220' instead of creating a new one.
# [I 2022-07-11 15:08:12,393] Using an existing study with name 'rl-612' instead of creating a new one.
# [I 2022-07-11 15:08:12,727] Using an existing study with name 'rl-75' instead of creating a new one.
# [I 2022-07-11 15:08:12,995] Using an existing study with name 'rl-60' instead of creating a new one.
# [I 2022-07-11 15:08:13,301] Using an existing study with name 'rl-17' instead of creating a new one.
